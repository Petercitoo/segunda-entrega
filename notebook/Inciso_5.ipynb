# %%
import sys
sys.path.append("../")
from src.Ejercicio_5 import ingreso_datos,calculo_envio

weight,dest = ingreso_datos()
calculo_envio(weight,dest)
# Out:
# Ingrese el peso del paquete en kgs:  5
# Elija el destino:
#  1.Local
#  2.Regional
#  3.Nacional  2
# El coste de envio sera de 2500$
