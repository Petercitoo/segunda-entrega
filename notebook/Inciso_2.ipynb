# %%
import sys
sys.path.append("../")
from src.Ejercicio_2 import crearLista, minSegs,minMax

playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

ms = crearLista(playlist)

totM, totS = minSegs(ms)

cancionMin, minDur, cancionMax, maxDur = minMax(ms,playlist)

print(f"La duracion total es {totM} m {totS} s")
print("-"*30)
print(f"La cancion mas larga es {cancionMax} con {maxDur}, mientras que la mas corta es {cancionMin} con {minDur}")
# Out:
# La duracion total es 46 m 53 s
# ------------------------------
# La cancion mas larga es Stairway to Heaven con 8:02, mientras que la mas corta es Imagine con 3:07
