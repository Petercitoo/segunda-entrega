# %%
import sys
sys.path.append("../")
from src.Ejercicio_8 import input_word, cipher, decipher

palabra, desplazamiento  = input_word()
palabra_cifrada = cipher(palabra,desplazamiento)
print(palabra_cifrada)
palabra_descifrada = decipher(palabra_cifrada,desplazamiento)
print(palabra_descifrada)
# Out:
# Ingrese la contraseña a cifrar:
#  Hola mundo!
# Ingrese el desplazamiento:
#  3
# Krod pxqgr!
# Hola mundo!
