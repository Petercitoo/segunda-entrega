# %%
import sys
sys.path.append("../")
from src.Ejercicio_7 import amigo_inv

amigo_inv()
# Out:
# Porfavor ingrese los nombres de los participantes separados por comas.
#  pedro,juan,juan,maria,luz,lucia, lucia, maria, lucia, luz, juan
# {'pedro': 'lucia', 'lucia': 'pedro', 'maria': 'juan', 'juan': 'luz', 'luz': 'maria'}
