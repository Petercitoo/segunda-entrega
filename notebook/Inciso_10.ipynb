# %%
import sys
sys.path.append("../")
from src.Ejercicio_10 import processing_rounds
rounds = [
    {
        'theme': 'Entrada',
        'scores': {
            'Valentina': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
            'Mateo':     {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
            'Camila':    {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
            'Santiago':  {'judge_1': 6, 'judge_2': 7, 'judge_3': 6},
            'Lucía':     {'judge_1': 8, 'judge_2': 8, 'judge_3': 8},
        }
    },
    {
        'theme': 'Plato principal',
        'scores': {
            'Valentina': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
            'Mateo':     {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
            'Camila':    {'judge_1': 7, 'judge_2': 6, 'judge_3': 7},
            'Santiago':  {'judge_1': 9, 'judge_2': 8, 'judge_3': 8},
            'Lucía':     {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
        }
    },
    {
        'theme': 'Postre',
        'scores': {
            'Valentina': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
            'Mateo':     {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
            'Camila':    {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
            'Santiago':  {'judge_1': 7, 'judge_2': 7, 'judge_3': 6},
            'Lucía':     {'judge_1': 9, 'judge_2': 9, 'judge_3': 9},
        }
    },
    {
        'theme': 'Cocina internacional',
        'scores': {
            'Valentina': {'judge_1': 8, 'judge_2': 9, 'judge_3': 9},
            'Mateo':     {'judge_1': 7, 'judge_2': 6, 'judge_3': 7},
            'Camila':    {'judge_1': 9, 'judge_2': 8, 'judge_3': 8},
            'Santiago':  {'judge_1': 8, 'judge_2': 9, 'judge_3': 7},
            'Lucía':     {'judge_1': 7, 'judge_2': 7, 'judge_3': 8},
        }
    },
    {
        'theme': 'Final libre',
        'scores': {
            'Valentina': {'judge_1': 9, 'judge_2': 8, 'judge_3': 9},
            'Mateo':     {'judge_1': 8, 'judge_2': 9, 'judge_3': 8},
            'Camila':    {'judge_1': 7, 'judge_2': 7, 'judge_3': 7},
            'Santiago':  {'judge_1': 9, 'judge_2': 9, 'judge_3': 9},
            'Lucía':     {'judge_1': 8, 'judge_2': 8, 'judge_3': 7},
        }
    }
]

processing_rounds(rounds)
# Out:
# Ronda 0 - Entrada:
#  Ganador: Camila con 26
#
# Progresion
#
# Camila: Puntos: 26 | Victorias: 1  | Mejor ronda:26 | Un promedio de: 26.0
#
# Valentina: Puntos: 24 | Victorias: 0  | Mejor ronda:24 | Un promedio de: 24.0
#
# Mateo: Puntos: 22 | Victorias: 0  | Mejor ronda:22 | Un promedio de: 22.0
#
# Santiago: Puntos: 19 | Victorias: 0  | Mejor ronda:19 | Un promedio de: 19.0
#
# Lucía: Puntos: 24 | Victorias: 0  | Mejor ronda:24 | Un promedio de: 24.0
#
#
# Ronda 1 - Plato principal:
#  Ganador: Valentina con 26
#
# Progresion
#
# Valentina: Puntos: 50 | Victorias: 1  | Mejor ronda:26 | Un promedio de: 24.0
#
# Camila: Puntos: 46 | Victorias: 1  | Mejor ronda:26 | Un promedio de: 26.0
#
# Mateo: Puntos: 46 | Victorias: 0  | Mejor ronda:24 | Un promedio de: 22.0
#
# Santiago: Puntos: 44 | Victorias: 0  | Mejor ronda:25 | Un promedio de: 19.0
#
# Lucía: Puntos: 46 | Victorias: 0  | Mejor ronda:24 | Un promedio de: 24.0
#
#
# Ronda 2 - Postre:
#  Ganador: Lucía con 27
#
# Progresion
#
# Valentina: Puntos: 72 | Victorias: 1  | Mejor ronda:26 | Un promedio de: 24.0
#
# Camila: Puntos: 70 | Victorias: 1  | Mejor ronda:26 | Un promedio de: 26.0
#
# Lucía: Puntos: 73 | Victorias: 1  | Mejor ronda:27 | Un promedio de: 24.0
#
# Mateo: Puntos: 72 | Victorias: 0  | Mejor ronda:26 | Un promedio de: 22.0
#
# Santiago: Puntos: 64 | Victorias: 0  | Mejor ronda:25 | Un promedio de: 19.0
#
#
# Ronda 3 - Cocina internacional:
#  Ganador: Valentina con 26
#
# Progresion
#
# Valentina: Puntos: 98 | Victorias: 2  | Mejor ronda:26 | Un promedio de: 24.0
#
# Camila: Puntos: 95 | Victorias: 1  | Mejor ronda:26 | Un promedio de: 26.0
#
# Lucía: Puntos: 95 | Victorias: 1  | Mejor ronda:27 | Un promedio de: 24.0
#
# Mateo: Puntos: 92 | Victorias: 0  | Mejor ronda:26 | Un promedio de: 22.0
#
# Santiago: Puntos: 88 | Victorias: 0  | Mejor ronda:25 | Un promedio de: 19.0
#
#
# Ronda 4 - Final libre:
#  Ganador: Santiago con 27
#
# Progresion
#
# Valentina: Puntos: 124 | Victorias: 2  | Mejor ronda:26 | Un promedio de: 24.0
#
# Camila: Puntos: 116 | Victorias: 1  | Mejor ronda:26 | Un promedio de: 26.0
#
# Santiago: Puntos: 115 | Victorias: 1  | Mejor ronda:27 | Un promedio de: 19.0
#
# Lucía: Puntos: 118 | Victorias: 1  | Mejor ronda:27 | Un promedio de: 24.0
#
# Mateo: Puntos: 117 | Victorias: 0  | Mejor ronda:26 | Un promedio de: 22.0
#
#  Cocinero        Puntaje         Rondas ganadas       Mejor ronda     Promedio
# -------------------------------------------------------------------------------
#  Valentina       124             2                    26              24.0
#  Mateo           117             0                    26              22.0
#  Camila          116             1                    26              26.0
#  Santiago        115             1                    27              19.0
#  Lucía           118             1                    27              24.0
# -------------------------------------------------------------------------------
